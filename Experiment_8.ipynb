# %% [markdown]
# <a href="https://colab.research.google.com/github/AsitSrivastava06/NumPy/blob/main/Experiment_8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Experiment-8
# ## TITLE: Tools in EDA - Numpy Pandas
# ### NAME: ASIT SRIVASTAVA
# #### BATCH:A2
# #### PRN:25070123026

# %%
#Declaration of Numpy
import numpy as np

a = np.array([10,20,30,40])
b = np.array([[1,2,3],[4,5,6]])
print(a)
print(b)
# Out:
# [10 20 30 40]
# [[1 2 3]
#  [4 5 6]]

# %%
#Dimension of Array
print(a.ndim)
print(b.ndim)
# Out:
# 1
# 2

# %%
print(a.shape) # how many elements in 1D
print(b.shape) # how many rows & columns in 2D
# Out:
# (4,)
# (2, 3)

# %%
print(a.dtype)
print(b.dtype)
# Out:
# int64
# int64

# %%
#In Built funcions using numpy
np.zeros((2,3))
# Out:
# array([[0., 0., 0.],
#        [0., 0., 0.]])

# %%
np.ones((3,3))
# Out:
# array([[1., 1., 1.],
#        [1., 1., 1.],
#        [1., 1., 1.]])

# %%
np.eye((3))
# Out:
# array([[1., 0., 0.],
#        [0., 1., 0.],
#        [0., 0., 1.]])

# %%
np.arange(1,10,2)
# Out:
# array([1, 3, 5, 7, 9])

# %%
np.linspace(0,1,5)
# Out:
# array([0.  , 0.25, 0.5 , 0.75, 1.  ])

# %%
c= a*2
d=a+5
print(c)
print(d)
# Out:
# [20 40 60 80]
# [15 25 35 45]

# %%
print(a)
print(a+5)
# Out:
# [10 20 30 40]
# [15 25 35 45]

# %%
np.mean(a)
# Out:
# np.float64(25.0)

# %%
np.median(a)
# Out:
# np.float64(25.0)

# %%
np.max(a)
# Out:
# np.int64(40)

# %%
np.min(a)
# Out:
# np.int64(10)

# %%
np.sum(a)
# Out:
# np.int64(100)
